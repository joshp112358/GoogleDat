# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import random
from scipy import stats

# %%
with open("./n53_m14/measurements_n53_m14_s0_e0_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data = list(reader)
    
with open("./n53_m14/measurements_n53_m14_s0_e11_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data1 = list(reader)
with open("./n53_m14/measurements_n53_m14_s1_e0_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data2 = list(reader)
with open("./n53_m14/measurements_n53_m14_s1_e11_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data3 = list(reader)
    
    
with open("./n53_m14/measurements_n53_m14_s2_e0_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data4 = list(reader)
    
with open("./n53_m14/measurements_n53_m14_s2_e11_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data5 = list(reader)
    
with open("./n53_m14/measurements_n53_m14_s3_e0_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    
    data6 = list(reader)
with open("./n53_m14/measurements_n53_m14_s3_e11_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data7 = list(reader)
with open("./n53_m14/measurements_n53_m14_s4_e0_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data8 = list(reader)
    
with open("./n53_m14/measurements_n53_m14_s4_e11_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data9 = list(reader)
with open("./n53_m14/measurements_n53_m14_s5_e0_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data10 = list(reader)
with open("./n53_m14/measurements_n53_m14_s5_e11_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data11 = list(reader)
with open("./n53_m14/measurements_n53_m14_s6_e0_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data12 = list(reader)
with open("./n53_m14/measurements_n53_m14_s6_e11_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data13 = list(reader)
with open("./n53_m14/measurements_n53_m14_s9_e11_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data14 = list(reader)

    
with open("./n53_m14/measurements_n53_m14_s7_e11_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data15 = list(reader)
with open("./n53_m14/measurements_n53_m14_s7_e0_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data16 = list(reader)
with open("./n53_m14/measurements_n53_m14_s8_e0_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data17 = list(reader)
with open("./n53_m14/measurements_n53_m14_s8_e11_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data18 = list(reader)
with open("./n53_m14/measurements_n53_m14_s9_e0_pEFGH.txt", newline='') as f:
    reader = csv.reader(f)
    reader = csv.reader(f)
    data19 = list(reader)

# %%
x0 = [list(map(int, n[0])) for n in data]
x1 = [list(map(int, n[0])) for n in data1]
x2 = [list(map(int, n[0])) for n in data2]
x3 = [list(map(int, n[0])) for n in data3]
x4 = [list(map(int, n[0])) for n in data4]
x5 = [list(map(int, n[0])) for n in data5]
x6 = [list(map(int, n[0])) for n in data6]
x7 = [list(map(int, n[0])) for n in data7]
x8 = [list(map(int, n[0])) for n in data8]
x9 = [list(map(int, n[0])) for n in data9]
x10 = [list(map(int, n[0])) for n in data10]
x11 = [list(map(int, n[0])) for n in data11]
x12 = [list(map(int, n[0])) for n in data12]
x13 = [list(map(int, n[0])) for n in data13]
x14 = [list(map(int, n[0])) for n in data14]
x15 = [list(map(int, n[0])) for n in data15]
x16 = [list(map(int, n[0])) for n in data16]
x17 = [list(map(int, n[0])) for n in data17]
x18 = [list(map(int, n[0])) for n in data18]
x19 = [list(map(int, n[0])) for n in data19]

# %%
A0 = np.array(x0)
A1 = np.array(x1)
A2 = np.array(x2)
A3 = np.array(x3)
A4 = np.array(x4)
A5 = np.array(x5)
A6 = np.array(x6)
A7 = np.array(x7)
A8 = np.array(x8)
A9 = np.array(x9)
A10 = np.array(x10)
A11 = np.array(x11)
A12 = np.array(x12)
A13 = np.array(x13)
A14 = np.array(x14)
A15 = np.array(x15)
A16 = np.array(x6)
A17 = np.array(x17)
A18 = np.array(x18)
A19 = np.array(x19)

# %%
s = np.linalg.svd(A0, compute_uv=False)
y0 = A0.dot(s)
y0 = np.sort(y0)

s = np.linalg.svd(A1, compute_uv=False)
y1 = A1.dot(s)
y1 = np.sort(y1)

s = np.linalg.svd(A2, compute_uv=False)
y2 = A2.dot(s)
y2 = np.sort(y2)

s = np.linalg.svd(A3, compute_uv=False)
y3 = A3.dot(s)
y3 = np.sort(y3)

s = np.linalg.svd(A4, compute_uv=False)
y4 = A4.dot(s)
y4 = np.sort(y4)

s = np.linalg.svd(A5, compute_uv=False)
y5 = A5.dot(s)
y5 = np.sort(y5)

s = np.linalg.svd(A6, compute_uv=False)
y6 = A6.dot(s)
y6 = np.sort(y6)

s = np.linalg.svd(A7, compute_uv=False)
y7 = A7.dot(s)
y7 = np.sort(y7)

s = np.linalg.svd(A8, compute_uv=False)
y8 = A8.dot(s)
y8 = np.sort(y8)

s = np.linalg.svd(A9, compute_uv=False)
y9 = A9.dot(s)
y9 = np.sort(y9)

s = np.linalg.svd(A10, compute_uv=False)
y10 = A10.dot(s)
y10 = np.sort(y10)

s = np.linalg.svd(A11, compute_uv=False)
y11 = A11.dot(s)
y11 = np.sort(y11)

s = np.linalg.svd(A12, compute_uv=False)
y12 = A12.dot(s)
y12 = np.sort(y12)

s = np.linalg.svd(A13, compute_uv=False)
y13 = A13.dot(s)
y13 = np.sort(y13)

s = np.linalg.svd(A14, compute_uv=False)
y14 = A14.dot(s)
y14 = np.sort(y14)

s = np.linalg.svd(A15, compute_uv=False)
y15 = A5.dot(s)
y15 = np.sort(y15)

s = np.linalg.svd(A16, compute_uv=False)
y16 = A16.dot(s)
y16 = np.sort(y16)

s = np.linalg.svd(A17, compute_uv=False)
y17 = A17.dot(s)
y17 = np.sort(y17)

s = np.linalg.svd(A18, compute_uv=False)
y18 = A18.dot(s)
y18 = np.sort(y18)

s = np.linalg.svd(A19, compute_uv=False)
y19 = A19.dot(s)
y19 = np.sort(y19)
